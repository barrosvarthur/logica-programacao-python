# %% [markdown]
# <a href="https://colab.research.google.com/github/barrosvarthur/logica_programacao_python/blob/main/L%C3%B3gica_Programa%C3%A7%C3%A3o_Python_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 01 - Escreva um programa que pergunte a velocidade de um carro. Caso ultrapasse 80Km/h,
# exiba uma mensagem dizendo que o usuário foi multado. Nesse caso, exiba o valor da multa,
# cobrando R$5 por cada Km acima da velocidade permitida

speed = int(input("Insira a velocidade do veículo, em km/h: "))

tax = (speed - 80) * 5

if speed < 0:
  print("Velocidade inválida.")
elif speed > 80:
  print(f"Multado\nValor da multa: R$ {tax}")
else:
  print("Velocidade permitida.")
# Out:
# Insira a velocidade do veículo, em km/h: 85
# Multado
# Valor da multa: R$ 25

# %%
# 02 - Crie um programa que leia duas notas de um aluno e calcule a sua média, mostrando uma
# mensagem no final, de acordo com a média atingida: Média até 4.9: REPROVADO; Média entre
# 5.0 e 6.9: RECUPERAÇÃO e Média 7.0 ou superior: APROVADO

note1 = float(input("Insira a primeira nota: "))
note2 = float(input("Agora insira a segunda nota: "))

med = (note1 + note2) / 2

if (note1 or note2) < 0 or (note1 or note2) > 10:
  print("Alguma nota é inválida.")
elif med < 5:
  print("REPROVADO.")
elif med < 7:
  print("RECUPERAÇÃO.")
else:
  print("APROVADO")
# Out:
# Insira a primeira nota: 10.1
# Agora insira a segunda nota: 10.1
# Alguma nota é inválida.

# %%
# 03 - Faça um programa que leia a largura e o comprimento de um terreno retangular,
# calculando e mostrando a sua área em m². O programa também deve mostrar a classificação
# desse terreno, de acordo com a lista abaixo: Abaixo de 100m² = TERRENO POPULAR; Entre
# 100m² e 500m² = TERRENO MASTER e Acima de 500m² = TERRENO VIP

width = float(input("Insira a largura do terreno: "))
length = float(input("Insira o comprimento do terreno: "))

area = width * length

if width < 0 or length < 0:
  print("A largura ou o comprimento é inválido.")
elif area < 100:
  print("TERRENO POPULAR")
elif area <= 500:
  print("TERRENO MASTER")
else:
  print("TERRENO VIP")
# Out:
# Insira a largura do terreno: 10
# Insira o comprimento do terreno: 50.1
# TERRENO VIP

# %%
# 04 - O Índice de Massa Corpórea (IMC) é um valor calculado baseado na altura e no peso de
# uma pessoa. De acordo com o valor do IMC, podemos classificar o indivíduo dentro de certas
# faixas. abaixo de 18.5: Abaixo do peso
# entre 18.5 e 25: Peso ideal
# entre 25 e 30: Sobrepeso
# entre 30 e 40: Obesidade
# acima de 40: Obesidade mórbida
# Obs: O IMC é calculado pela expressão peso/altura² (peso dividido pelo quadrado da altura)

weight = float(input("Insira o seu peso (kg): "))
height = float(input("Insira sua altura (m): "))

imc = weight / (height ** 2)

print(f"IMC = {imc}")

if weight < 0 or length < 0:
  print("Peso/Altura inválido(a).")
elif imc < 18.5:
  print("Abaixo do peso.")
elif imc < 25:
  print("Peso ideal.")
elif imc < 30:
  print("Sobrepeso.")
elif imc < 40:
  print("Obesidade.")
else:
  print("Obesidade mórbida.")
# Out:
# Insira o seu peso (kg): 71
# Insira sua altura (m): 1.685
# IMC = 25.006824045294046
# Sobrepeso.

# %%
# 05 - Escreva um programa que leia números inteiros do teclado. O programa deve ler os
# números até que o usuário digite 0 (zero). No final da execução, exiba a quantidade de
# números digitados, assim como a soma e a média aritmética.
number = int(input("Digite números inteiros. Quando cansar, digite '0': "))

while True:
  counter += 1
  sum += number
  number = int(input("Digite números inteiros. Quando cansar, digite '0': "))

  if number == 0:
    print("\n")
    print(f"Quantidade de números digitados: {counter}")
    print(f"Soma dos números digitados: {sum}")
    print(f"Média dos números digitados: {sum / counter}")
    break
# Out:
# Digite números inteiros. Quando cansar, digite '0': 7
# Digite números inteiros. Quando cansar, digite '0': 8
# Digite números inteiros. Quando cansar, digite '0': 9
# Digite números inteiros. Quando cansar, digite '0': 0
#
#
# Quantidade de números digitados: 18
# Soma dos números digitados: 93
# Média dos números digitados: 5.166666666666667
